# %%
import pandas as pd

# %%
df = pd.read_table("Данные\Калибровка_041224_145832_.txt")
df.head()
# Out:
#        Timestamp       Current  Wavelength  Shutter
# 0  041224_145842  5.636900e-11         300      0.0
# 1  041224_145843  5.743200e-11         300      0.0
# 2  041224_145843  5.557400e-11         300      0.0
# 3  041224_145843  5.677800e-11         300      0.0
# 4  041224_145843  7.192100e-11         300      0.0

# %%
time_data = df.Timestamp[10]
time_data
# Out:
# '041224_145843'

# %%
from datetime import datetime

format_data = "%d%m%y_%H%M%S"
date0 = datetime.strptime(time_data, format_data)
date0
# Out:
# datetime.datetime(2024, 12, 4, 14, 58, 43)

# %%
date1 = datetime.strptime(df.Timestamp[20], format_data)
date1
# Out:
# datetime.datetime(2024, 12, 4, 14, 58, 44)

# %%
import datetime as dt
date1 - date0
# Out:
# datetime.timedelta(seconds=1)

# %%
df["Time"] = df.Timestamp.apply( lambda x: datetime.strptime(x, format_data))
df["Time"] = df["Time"] - df["Time"][0]
df
# Out:
#            Timestamp       Current  Wavelength  Shutter            Time
# 0      041224_145842  5.636900e-11         300      0.0 0 days 00:00:00
# 1      041224_145843  5.743200e-11         300      0.0 0 days 00:00:01
# 2      041224_145843  5.557400e-11         300      0.0 0 days 00:00:01
# 3      041224_145843  5.677800e-11         300      0.0 0 days 00:00:01
# 4      041224_145843  7.192100e-11         300      0.0 0 days 00:00:01
# ...              ...           ...         ...      ...             ...
# 10809  041224_151500  5.153920e-10         595      0.0 0 days 00:16:18
# 10810  041224_151500  5.178290e-10         595      0.0 0 days 00:16:18
# 10811  041224_151500  5.346380e-10         595      0.0 0 days 00:16:18
# 10812  041224_151500  5.354970e-10         595      0.0 0 days 00:16:18
# 10813  041224_151500  5.069820e-10         600      0.0 0 days 00:16:18
#
# [10814 rows x 5 columns]

# %%
df["Time"] = df["Time"].dt.total_seconds()
df
# Out:
#            Timestamp       Current  Wavelength  Shutter   Time
# 0      041224_145842  5.636900e-11         300      0.0    0.0
# 1      041224_145843  5.743200e-11         300      0.0    1.0
# 2      041224_145843  5.557400e-11         300      0.0    1.0
# 3      041224_145843  5.677800e-11         300      0.0    1.0
# 4      041224_145843  7.192100e-11         300      0.0    1.0
# ...              ...           ...         ...      ...    ...
# 10809  041224_151500  5.153920e-10         595      0.0  978.0
# 10810  041224_151500  5.178290e-10         595      0.0  978.0
# 10811  041224_151500  5.346380e-10         595      0.0  978.0
# 10812  041224_151500  5.354970e-10         595      0.0  978.0
# 10813  041224_151500  5.069820e-10         600      0.0  978.0
#
# [10814 rows x 5 columns]

# %%
df[df.Time == 1]
# Out:
#         Timestamp       Current  Wavelength  Shutter  Time
# 1   041224_145843  5.743200e-11         300      0.0   1.0
# 2   041224_145843  5.557400e-11         300      0.0   1.0
# 3   041224_145843  5.677800e-11         300      0.0   1.0
# 4   041224_145843  7.192100e-11         300      0.0   1.0
# 5   041224_145843  4.693000e-11         300      0.0   1.0
# 6   041224_145843  6.171700e-11         300      0.0   1.0
# 7   041224_145843  6.641600e-11         300      0.0   1.0
# 8   041224_145843  7.886500e-11         300      0.0   1.0
# 9   041224_145843  9.829300e-11         300      0.0   1.0
# 10  041224_145843  9.590200e-11         300      0.0   1.0
# 11  041224_145843  1.072290e-10         300      0.0   1.0
# 12  041224_145843  1.184980e-10         300      0.0   1.0

# %%
pattern = np.linspace(0,1,12)
df.loc[df.Time == 1, "Time"] += pattern
df.head(20)
# Out:
#         Timestamp       Current  Wavelength  Shutter      Time
# 0   041224_145842  5.636900e-11         300      0.0  0.000000
# 1   041224_145843  5.743200e-11         300      0.0  1.000000
# 2   041224_145843  5.557400e-11         300      0.0  1.090909
# 3   041224_145843  5.677800e-11         300      0.0  1.181818
# 4   041224_145843  7.192100e-11         300      0.0  1.272727
# 5   041224_145843  4.693000e-11         300      0.0  1.363636
# 6   041224_145843  6.171700e-11         300      0.0  1.454545
# 7   041224_145843  6.641600e-11         300      0.0  1.545455
# 8   041224_145843  7.886500e-11         300      0.0  1.636364
# 9   041224_145843  9.829300e-11         300      0.0  1.727273
# 10  041224_145843  9.590200e-11         300      0.0  1.818182
# 11  041224_145843  1.072290e-10         300      0.0  1.909091
# 12  041224_145843  1.184980e-10         300      0.0  2.000000
# 13  041224_145844  1.273530e-10         300      0.0  2.000000
# ...

# %%
df[-30:]
# Out:
#            Timestamp       Current  Wavelength  Shutter   Time
# 10784  041224_151458  5.283960e-10         595      0.0  976.0
# 10785  041224_151458  5.338440e-10         595      0.0  976.0
# 10786  041224_151458  5.188060e-10         595      0.0  976.0
# 10787  041224_151458  5.172450e-10         595      0.0  976.0
# 10788  041224_151458  5.394140e-10         595      0.0  976.0
# 10789  041224_151458  5.327450e-10         595      0.0  976.0
# 10790  041224_151458  5.008690e-10         595      0.0  976.0
# 10791  041224_151458  5.162630e-10         595      0.0  976.0
# 10792  041224_151458  5.355850e-10         595      0.0  976.0
# 10793  041224_151458  5.114590e-10         595      0.0  976.0
# 10794  041224_151459  5.292610e-10         595      0.0  977.0
# 10795  041224_151459  5.186770e-10         595      0.0  977.0
# 10796  041224_151459  5.108690e-10         595      0.0  977.0
# 10797  041224_151459  5.258430e-10         595      0.0  977.0
# ...

# %%
for i in range(int(df.Time[df.index[-1]])):
    pattern = np.linspace(0,1,len(df[df.Time == i]))
    df.loc[df.Time == i, "Time"] += pattern
df.head(30)
# Out:
#         Timestamp       Current  Wavelength  Shutter      Time
# 0   041224_145842  5.636900e-11         300      0.0  0.000000
# 1   041224_145843  5.743200e-11         300      0.0  1.000000
# 2   041224_145843  5.557400e-11         300      0.0  1.090909
# 3   041224_145843  5.677800e-11         300      0.0  1.181818
# 4   041224_145843  7.192100e-11         300      0.0  1.272727
# 5   041224_145843  4.693000e-11         300      0.0  1.363636
# 6   041224_145843  6.171700e-11         300      0.0  1.454545
# 7   041224_145843  6.641600e-11         300      0.0  1.545455
# 8   041224_145843  7.886500e-11         300      0.0  1.636364
# 9   041224_145843  9.829300e-11         300      0.0  1.727273
# 10  041224_145843  9.590200e-11         300      0.0  1.818182
# 11  041224_145843  1.072290e-10         300      0.0  1.909091
# 12  041224_145843  1.184980e-10         300      0.0  2.000000
# 13  041224_145844  1.273530e-10         300      0.0  2.083333
# ...

# %%
import plotly.express as px
px.line(df, "Time", ["Current","Wavelength", "Shutter"])

# %%
df["Current_uA"] = df["Current"] * 3E7

# %%
px.line(df.loc[df["Wavelength"] == 350], "Time", ["Current_uA", "Shutter"])

# %%
df["Shutter"] = df["Shutter"].shift(-23)

# %%
px.line(df.loc[df["Wavelength"] == 400], "Time", ["Current_uA", "Shutter"])

# %%
IPCE_df = pd.DataFrame([])
df = df.dropna()
for wavelength in df["Wavelength"].unique():
    mono_df = df.loc[df["Wavelength"] == wavelength]
    light_df = mono_df.loc[df.Shutter == 1, "Current"]
    light_df = light_df[10:-2]
    IPCE = light_df.median() - mono_df[-50:]["Current"].median()
    new_row = pd.DataFrame({"Wavelength": wavelength, "IPCE": IPCE}, index=[0])
    IPCE_df = pd.concat([IPCE_df, new_row])
IPCE_df.plot(x="Wavelength")
# Out:
# <Axes: xlabel='Wavelength'>

# %%
#Продолжу потом
